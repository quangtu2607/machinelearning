# %%
#PROBLEM1
import numpy as np

np.random.seed(0)

x = np.random.randint(-50, high=50, size=1001)
y = 1/2*x + 1
print(x)
print(y)
# Out:
# [-6 -3 14 ...  4 46 32]
# [-2.  -0.5  8.  ...  3.  24.  17. ]

# %%
#PROBLEM2
import numpy as np

np.random.seed(0)

x = np.random.randint(-50, high=50, size=1001)
y = 1/2*x + 1

np.column_stack((x, y))
# Out:
# array([[-6. , -2. ],
#        [-3. , -0.5],
#        [14. ,  8. ],
#        ...,
#        [ 4. ,  3. ],
#        [46. , 24. ],
#        [32. , 17. ]])

# %%
#PROBLEM3
import numpy as np

np.random.seed(0)

x = np.random.randint(-50, high=50, size=1001)
y = 1/2*x + 1

d_x = x[1:] - x[:-1]
d_y = y[1:] - y[:-1]

gra = d_y / d_x
print(gra)
# Out:
# [0.5 0.5 0.5 nan 0.5 0.5 0.5 0.5 0.5 0.5 0.5 nan 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 nan 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  nan 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
# ...

# %%
#PROBLEM4
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)

x = np.random.randint(-50, high=50, size=1001)
y = 1/2*x + 1

d_x = x[1:] - x[:-1]
d_y = y[1:] - y[:-1]

gra = d_y / d_x

plt.title('Graph 1')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y)
plt.show()

plt.title('Graph 2')
plt.xlabel('x')
plt.ylabel('Gradient')
plt.plot(x[:-1], gra)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in true_divide
#   del sys.path[0]

# %%
#PROBLEM5
import numpy as np
import matplotlib.pyplot as plt

def compute_gradient(function, x_range=(-50, 50.1, 0.1)):
    """
    Calculate the gradient using the amount of change.
    Parameters
    ----------------
    function : function
      The function you want to find, the one that returns the ndarray of y when you put the ndarray of x.
    x_range : tuple
      Specify the range in the same way as the argument of np.arange ().
    Returns
    ----------------
    array_xy : ndarray, shape(n, 2)
      A combination of x and y. n depends on x_range.
    gradient : ndarray, shape(n-1,)
      Function gradient. One factor is reduced to make a difference
    """
    array_x = np.arange(-50, 50.1, 0.1)
    array_y = function(array_x)

    array_xy = np.column_stack((array_x, array_y))

    d_x = array_x[1:] - array_x[:-1]
    d_y = array_y[1:] - array_y[:-1]
    gradient = d_y / d_x 

    plt.title('Graph 1')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.plot(array_x, array_y)
    plt.show()

    plt.title('Graph 2')
    plt.xlabel('x')
    plt.ylabel('Gradient')
    plt.plot(array_x[:-1], gradient)
    plt.show()

    return array_xy, gradient

def function1(array_x):
    array_y = array_x**2

    return array_y

def function2(array_x):
    array_y = 2*array_x**2 + 2**array_x

    return array_y

def function3(array_x):
    array_y = np.sin(array_x**1/2)

    return array_y

np.set_printoptions(threshold=10)
array_xy, gradient = compute_gradient(function1)
print("Gradient: {}".format(gradient))
array_xy, gradient = compute_gradient(function2)
print("Gradient: {}".format(gradient))
array_xy, gradient = compute_gradient(function3, x_range=(0, 50.1, 0.1))
print("Gradient: {}".format(gradient))
# Out:
# Gradient: [-99.9 -99.7 -99.5 ...  99.5  99.7  99.9]
# Gradient: [-1.99800000e+02 -1.99400000e+02 -1.99000000e+02 ...  6.56379007e+14
#   7.03489601e+14  7.53981486e+14]
# Gradient: [0.49374088 0.48919868 0.48343374 ... 0.48343374 0.48919868 0.49374088]

# %%
#PROBLEM6a
import numpy as np
import matplotlib.pyplot as plt

def compute_min(function, x_range=(-50, 50.1, 0.1)):
    array_x = np.arange(-50, 50.1, 0.1)
    array_y = function(array_x)

    d_x = array_x[1:] - array_x[:-1]
    d_y = array_y[1:] - array_y[:-1]
    gradient = d_y / d_x 

    array_xgra = np.column_stack((array_x[:-1], gradient))

    min = np.amin(array_y)
    index = np.argmin(array_y)
    return min, index

def function1(array_x):
    array_y = array_x**2

    return array_y

def function2(array_x):
    array_y = 2*array_x**2 + 2**array_x

    return array_y

def function3(array_x):
    array_y = np.sin(array_x**1/2)

    return array_y

min, index = compute_min(function1)
print("Minimum: {} / Index: {}".format(min, index))
min, index = compute_min(function2)
print("Minimum: {} / Index: {}".format(min, index))
min, index = compute_min(function3, x_range=(0, 50.1, 0.1))
print("Minimum: {} / Index: {}".format(min, index))
# Out:
# Minimum: 5.048709793414476e-25 / Index: 500
# Minimum: 0.9505505632959851 / Index: 498
# Minimum: -0.9999920733059178 / Index: 343
